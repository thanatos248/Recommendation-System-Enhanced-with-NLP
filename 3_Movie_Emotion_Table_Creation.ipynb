# %% [markdown]
# # Mounting GoogleDrive

# %%
# Mounting Google-Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
import re
# !pip install demoji
import demoji
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: demoji in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %% [markdown]
# # Importing Dataset

# %%
# Importing Dataset
df = pd.read_csv('/content/gdrive/MyDrive/Capstone/movie_reviews.csv', index_col = 0)
df
# Out:
#                                      Movie  \
# 0      http://www.imdb.com/title/tt0108921
# 1      http://www.imdb.com/title/tt0366707
# 2      http://www.imdb.com/title/tt0096657
# 3      http://www.imdb.com/title/tt0044079
# 4      http://www.imdb.com/title/tt0138541
# ...                                    ...
# 24995  http://www.imdb.com/title/tt0053054
# 24996  http://www.imdb.com/title/tt0079095
# 24997  http://www.imdb.com/title/tt0303397
# 24998  http://www.imdb.com/title/tt0762091
# 24999  http://www.imdb.com/title/tt0211492
#
#                                                   Review  Rating
# 0      I used to watch this show when I was growing u...       8
# 1      After seeing this DVD, I was floored. It is SO...      10
# 2      This TV series is about a foolish and unconven...       9
# 3      One would have expected Hitchcock's return to ...      10
# 4      But not too hip. And not too wisecracking. "Ju...      10
# ...                                                  ...     ...
# 24995  Excellent farce! Which, of course, is all it i...      10
# 24996  This movie earned every one of the ten votes I...      10
# 24997  Don't be swayed by the naysayers. This is a wo...       8
# 24998  I gave this movie such a high mark because it ...      10
# 24999  Walking home after the film, I was humming the...       7
#
# [25000 rows x 3 columns]

# %% [markdown]
# # Data Pre-Processing

# %%
# To remove Emojis and Emoticons
def emojis(tweet):
  dem = demoji.findall(tweet)
  for item in dem.keys():
    tweet = tweet.replace(item, ' ')
  return tweet

# %%
# To Remove HTML Tags
def Remove_HTML_Tags(tweet):
  tweet = re.sub(r'<.*?>', '', tweet)
  return tweet

# %%
# Importing Dictionary for common misspellings
# http://norvig.com/spell-correct.html
misspell_data = pd.read_csv('/content/gdrive/MyDrive/Capstone/Spell_Check/aspell.txt',
                                 sep = ':', names = ["correction","misspell"])
misspell_data.misspell = misspell_data.misspell.str.strip()
misspell_data.misspell = misspell_data.misspell.str.split(" ")
misspell_data = misspell_data.explode("misspell").reset_index(drop=True)
misspell_data.drop_duplicates("misspell",inplace=True)
miss_corr = dict(zip(misspell_data.misspell, misspell_data.correction))

# Sample of the dict
{v:miss_corr[v] for v in [list(miss_corr.keys())[k] for k in range(20)]}
# Out:
# {'Steffen': 'Stephen',
#  'abilitey': 'ability',
#  'abouy': 'about',
#  'absorbtion': 'absorption',
#  'accidently': 'accidentally',
#  'accomodate': 'accommodate',
#  'acommadate': 'accommodate',
#  'acord': 'accord',
#  'adultry': 'adultery',
#  'aggresive': 'aggressive',
#  'alchohol': 'alcohol',
#  'alchoholic': 'alcoholic',
#  'allieve': 'alive',
#  'alright': 'all_right',
#  'aquantance': 'acquaintance',
#  'equire': 'acquire',
#  'nevade': 'Nevada',
#  'presbyterian': 'Presbyterian',
#  'rsx': 'RSX',
#  'susan': 'Susan'}

# %%
# To correct misspelled words
def MisspelledCorrection(tweet):
  for x in tweet.split():
    if x in miss_corr.keys():
      tweet = tweet.replace(x, miss_corr[x])
  return tweet

# %%
# Import list of common English Contractions
contractions = pd.read_csv("/content/gdrive/MyDrive/Capstone/contractions.csv")
print(contractions)
cont_dic = dict(zip(contractions.Contraction, contractions.Meaning))
# Out:
#     Contraction       Meaning
# 0        'aight       alright
# 1         ain't        is not
# 2         amn't        am not
# 3        aren't       are not
# 4         can't        cannot
# ..          ...           ...
# 143    y'all're  you all are
# 144       you'd     you would
# 145      you'll      you will
# 146      you're       you are
# 147      you've      you have
#
# [148 rows x 2 columns]

# %%
# To Convert Contractions to their Meaning
def Cont_to_Meaning(tweet):
  for x in tweet.split():
    if x in cont_dic.keys():
      tweet = tweet.replace(x, cont_dic[x])
  return tweet

# %%
# Pre-processing Tweets
def cleaning(tweet):
  # Converting tweet to Lower Case
  tweet = tweet.lower()
  # Remove HTML Tags
  tweet = Remove_HTML_Tags(tweet)
  # Removing Mentions (@...) and Hashtags (#...)
  tweet = re.sub("@[A-Za-z0-9_]+","", tweet)
  tweet = re.sub("#[A-Za-z0-9_]+","", tweet)
  # Removing URL Links
  tweet = re.sub(r'https?:\/\/\S+', '', tweet)
  tweet = re.sub(r"www\.[a-z]?\.?(com)+|[a-z]+\.(com)", '', tweet)
  # Removing Placeholders sometimes found in some data
  tweet = re.sub(r'{link}', '', tweet)
  tweet = re.sub(r"\[video\]", '', tweet)
  # Remove emojis
  tweet = emojis(tweet)
  # Correct Spellings
  tweet = MisspelledCorrection(tweet)
  # Converting Contractions to their Meaning
  tweet = Cont_to_Meaning(tweet)
  return tweet

# %%
# Applying cleaning to all tweets
df['Review'] = df.Review.apply(lambda x: cleaning(x))
df
# Out:
#                                      Movie  \
# 0      http://www.imdb.com/title/tt0108921
# 1      http://www.imdb.com/title/tt0366707
# 2      http://www.imdb.com/title/tt0096657
# 3      http://www.imdb.com/title/tt0044079
# 4      http://www.imdb.com/title/tt0138541
# ...                                    ...
# 24995  http://www.imdb.com/title/tt0053054
# 24996  http://www.imdb.com/title/tt0079095
# 24997  http://www.imdb.com/title/tt0303397
# 24998  http://www.imdb.com/title/tt0762091
# 24999  http://www.imdb.com/title/tt0211492
#
#                                                   Review  Rating
# 0      i used to watch this show when i was growing u...       8
# 1      after seeing this dvd, i was floored. it is so...      10
# 2      this tv series is about a foolish and unconven...       9
# 3      one would have expected hitchcock's return to ...      10
# 4      but not too hip. and not too wisecracking. "ju...      10
# ...                                                  ...     ...
# 24995  excellent farce! which, of course, is all it i...      10
# 24996  this movie earned every one of the ten votes i...      10
# 24997  do not be swayed by the naysayers. this is a w...       8
# 24998  i gave this movie such a high mark because it ...      10
# 24999  walking home after the film, i was humming the...       7
#
# [25000 rows x 3 columns]

# %%
# Removing blank tweets after pre-processing
df['Review'].replace('', np.nan, inplace = True)
df.dropna(subset = ['Review'], inplace = True)
df
# Out:
#                                      Movie  \
# 0      http://www.imdb.com/title/tt0108921
# 1      http://www.imdb.com/title/tt0366707
# 2      http://www.imdb.com/title/tt0096657
# 3      http://www.imdb.com/title/tt0044079
# 4      http://www.imdb.com/title/tt0138541
# ...                                    ...
# 24995  http://www.imdb.com/title/tt0053054
# 24996  http://www.imdb.com/title/tt0079095
# 24997  http://www.imdb.com/title/tt0303397
# 24998  http://www.imdb.com/title/tt0762091
# 24999  http://www.imdb.com/title/tt0211492
#
#                                                   Review  Rating
# 0      i used to watch this show when i was growing u...       8
# 1      after seeing this dvd, i was floored. it is so...      10
# 2      this tv series is about a foolish and unconven...       9
# 3      one would have expected hitchcock's return to ...      10
# 4      but not too hip. and not too wisecracking. "ju...      10
# ...                                                  ...     ...
# 24995  excellent farce! which, of course, is all it i...      10
# 24996  this movie earned every one of the ten votes i...      10
# 24997  do not be swayed by the naysayers. this is a w...       8
# 24998  i gave this movie such a high mark because it ...      10
# 24999  walking home after the film, i was humming the...       7
#
# [25000 rows x 3 columns]

# %%
df["empty"]       = np.nan
df["sadness"]     = np.nan
df["enthusiasm"]  = np.nan
df["neutral"]     = np.nan
df["worry"]       = np.nan
df["surprise"]    = np.nan
df["love"]        = np.nan
df["fun"]         = np.nan
df["hate"]        = np.nan
df["happiness"]   = np.nan
df["boredom"]     = np.nan
df["relief"]      = np.nan
df["anger"]       = np.nan
df
# Out:
#                                      Movie  \
# 0      http://www.imdb.com/title/tt0108921
# 1      http://www.imdb.com/title/tt0366707
# 2      http://www.imdb.com/title/tt0096657
# 3      http://www.imdb.com/title/tt0044079
# 4      http://www.imdb.com/title/tt0138541
# ...                                    ...
# 24995  http://www.imdb.com/title/tt0053054
# 24996  http://www.imdb.com/title/tt0079095
# 24997  http://www.imdb.com/title/tt0303397
# 24998  http://www.imdb.com/title/tt0762091
# 24999  http://www.imdb.com/title/tt0211492
#
#                                                   Review  Rating  empty  \
# 0      i used to watch this show when i was growing u...       8    NaN
# 1      after seeing this dvd, i was floored. it is so...      10    NaN
# 2      this tv series is about a foolish and unconven...       9    NaN
# 3      one would have expected hitchcock's return to ...      10    NaN
# 4      but not too hip. and not too wisecracking. "ju...      10    NaN
# ...                                                  ...     ...    ...
# 24995  excellent farce! which, of course, is all it i...      10    NaN
# 24996  this movie earned every one of the ten votes i...      10    NaN
# 24997  do not be swayed by the naysayers. this is a w...       8    NaN
# 24998  i gave this movie such a high mark because it ...      10    NaN
# 24999  walking home after the film, i was humming the...       7    NaN
#
#        sadness  enthusiasm  neutral  worry  surprise  love  fun  hate  \
# 0          NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 1          NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 2          NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 3          NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 4          NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# ...        ...         ...      ...    ...       ...   ...  ...   ...
# 24995      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 24996      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 24997      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 24998      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 24999      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
#
#        happiness  boredom  relief  anger
# 0            NaN      NaN     NaN    NaN
# 1            NaN      NaN     NaN    NaN
# 2            NaN      NaN     NaN    NaN
# 3            NaN      NaN     NaN    NaN
# 4            NaN      NaN     NaN    NaN
# ...          ...      ...     ...    ...
# 24995        NaN      NaN     NaN    NaN
# 24996        NaN      NaN     NaN    NaN
# 24997        NaN      NaN     NaN    NaN
# 24998        NaN      NaN     NaN    NaN
# 24999        NaN      NaN     NaN    NaN
#
# [25000 rows x 16 columns]

# %%
df.to_csv('/content/gdrive/MyDrive/Capstone/movie_emotion.csv')

# %% [markdown]
# # Model

# %%
# !pip install transformers
import transformers
from transformers import TFAutoModel, AutoTokenizer
# !pip install tokenizers
from tokenizers import Tokenizer, models, pre_tokenizers, decoders, processors
from keras.preprocessing import sequence, text
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.embeddings import Embedding
from keras.utils import np_utils
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from keras.layers import GlobalMaxPooling1D, Conv1D, MaxPooling1D, Flatten, Bidirectional, SpatialDropout1D
from keras.preprocessing import sequence, text
import tensorflow as tf
import tqdm
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 5.2 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 27.5 MB/s
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 27.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 41.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.6 transformers-4.17.0
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.7/dist-packages (0.11.6)

# %%
import tensorflow as tf
from keras.preprocessing import sequence, text

# %%
# !pip install pyyaml h5py
import os
checkpoint_path = "/content/gdrive/MyDrive/Capstone/Checkpoints/cp.cpkt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.5)

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# '/content/gdrive/MyDrive/Capstone/Checkpoints/cp.cpkt'

# %%
from tensorflow import keras
model = keras.models.load_model('/content/gdrive/MyDrive/Capstone/my_model.h5')
model.summary()
model.load_weights(latest)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 160, 160)          4967040
#
#  spatial_dropout1d (SpatialD  (None, 160, 160)         0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 250)               411000
#
#  dense (Dense)               (None, 13)                3263
#
# =================================================================
# Total params: 5,381,303
# Trainable params: 5,381,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
token = text.Tokenizer(num_words=None)
max_len = 160

# %%
id  = {"empty":       0,
       "sadness":     1,
       "enthusiasm":  2,
       "neutral":     3,
       "worry":       4,
       "surprise":    5,
       "love":        6,
       "fun":         7,
       "hate":        8,
       "happiness":   9,
       "boredom":     10,
       "relief":      11,
       "anger":       12}

# %%
def get_sentiment(model,text):
    text = cleaning(text)
    #tokenize
    twt = token.texts_to_sequences([text])
    twt = sequence.pad_sequences(twt, maxlen=max_len, dtype='int32')
    sentiment = model.predict(twt,batch_size=1,verbose = 2)
    sent = np.round(np.dot(sentiment,100).tolist(),0)[0]
    result = pd.DataFrame([id.keys(),sent]).T
    result.columns = ["sentiment","percentage"]
    result=result[result.percentage !=0]
    return result

# %%
for index, row in df.iterrows():
  #print(row['Review'])
  result = get_sentiment(model, row['Review'])
  for result_index, result_row in result.iterrows():
    df.loc[index, result_row['sentiment']] = result_row['percentage']
# Out:
# 1/1 - 0s - 481ms/epoch - 481ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 0s - 95ms/epoch - 95ms/step
# 1/1 - 0s - 102ms/epoch - 102ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 0s - 91ms/epoch - 91ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-10379daf2c6b> in <module>()
#       1 for index, row in df.iterrows():
#       2   #print(row['Review'])
# ----> 3   result = get_sentiment(model, row['Review'])
#       4   for result_index, result_row in result.iterrows():
#       5     df.loc[index, result_row['sentiment']] = result_row['percentage']
#
# <ipython-input-18-49528148dcf2> in get_sentiment(model, text)
#       4     twt = token.texts_to_sequences([text])
#       5     twt = sequence.pad_sequences(twt, maxlen=max_len, dtype='int32')
# ----> 6     sentiment = model.predict(twt,batch_size=1,verbose = 2)
#       7     sent = np.round(np.dot(sentiment,100).tolist(),0)[0]
#       8     result = pd.DataFrame([id.keys(),sent]).T
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1976       callbacks.on_predict_begin()
#    1977       batch_outputs = None
# -> 1978       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1979         with data_handler.catch_stop_iteration():
#    1980           for step in data_handler.steps():
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                     Movie  \
# 0     http://www.imdb.com/title/tt0246299
# 1     http://www.imdb.com/title/tt0153998
# 2     http://www.imdb.com/title/tt0053270
# 3     http://www.imdb.com/title/tt0080716
# 4     http://www.imdb.com/title/tt0310778
# ...                                   ...
# 7993  http://www.imdb.com/title/tt0048021
# 7994  http://www.imdb.com/title/tt0048021
# 7995  http://www.imdb.com/title/tt0033727
# 7996  http://www.imdb.com/title/tt0223005
# 7997  http://www.imdb.com/title/tt0086525
#
#                                                  Review Rating  empty  \
# 0     one of, if not the most visually beautiful fil...      9    NaN
# 1     i loved the great lighting and was warmed by t...      8    NaN
# 2     the remarkable, sometimes infuriating, often b...      8    NaN
# 3     although at first glance this movie looks like...      8    NaN
# 4     in paris, a few months before the nazi invasio...      9    NaN
# ...                                                 ...    ...    ...
# 7993  fantastic movie! one of the best film noir mov...     10    NaN
# 7994  the fact that after 50 years, it is still a hi...      8    NaN
# 7995  mr. bug goes to town was one of those films th...      8    NaN
# 7996  even the trailer for this movie makes me cry, ...     10    NaN
# 7997  there were a lot of dumb teenage getting sex m...      7    NaN
#
#       sadness  enthusiasm  neutral  worry  surprise  love  fun  hate  \
# 0         NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 1         NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 2         NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 3         NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 4         NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# ...       ...         ...      ...    ...       ...   ...  ...   ...
# 7993      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 7994      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 7995      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 7996      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
# 7997      NaN         NaN      NaN    NaN       NaN   NaN  NaN   NaN
#
#       happiness  boredom  relief  anger
# 0           NaN      NaN     NaN    NaN
# 1           NaN      NaN     NaN    NaN
# 2           NaN      NaN     NaN    NaN
# 3           NaN      NaN     NaN    NaN
# 4           NaN      NaN     NaN    NaN
# ...         ...      ...     ...    ...
# 7993        NaN      NaN     NaN    NaN
# 7994        NaN      NaN     NaN    NaN
# 7995        NaN      NaN     NaN    NaN
# 7996        NaN      NaN     NaN    NaN
# 7997        NaN      NaN     NaN    NaN
#
# [7998 rows x 16 columns]

# %%
result = get_sentiment(model,"I hate this game so much,It make me angry all the time ")
print(result)
# Out:
# 1/1 - 0s - 484ms/epoch - 484ms/step
#      sentiment percentage
# 0        empty       11.0
# 1      sadness        2.0
# 2   enthusiasm        2.0
# 3      neutral       66.0
# 4        worry        4.0
# 5     surprise        3.0
# 6         love        3.0
# 7          fun        1.0
# 8         hate        1.0
# 9    happiness        3.0
# 11      relief        3.0
